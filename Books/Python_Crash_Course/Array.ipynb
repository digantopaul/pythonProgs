# %%
#Creating an array of signed integers

from array import array

# int_array = array("i",[1,2,3,4,5])
# print(int_array)
# int_array.append(6)
# print(int_array)
# int_array.append(6)
# print(int_array)

int_array = array("i",[1,2,3,4,5])
# ch_array = array("B", [ord(c) for c in ("A", "B", "C")])

ch_array = array("u", ['a','b','f'])

print(ch_array[0])


# int_array = array("i", [65,66,67])

# for i in int_array:
#     print(chr(i))
# Out:
# a
