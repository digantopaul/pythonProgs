# %%
#Program to delete the duplicates and order the list
a = [2,2,4,1,5,1,6,5,7,6,1,8,9]

#Method 1
b = []
# for val in a:
#     if val not in b:
#         b.append(val)
b

#method 2
#[b.append(val) for val in a if val not in b]
b

#Method 3
# b = list(dict.fromkeys(a))
print(b)

#Method 4
#b = list(set(a))
b
# Out:
# [1, 2, 4, 5, 6, 7, 8, 9]
